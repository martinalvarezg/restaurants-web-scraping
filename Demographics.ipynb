# %%
# !where python
# Out:
# C:\Python312\python.exe
# C:\Users\marti\miniconda3\python.exe
# C:\Users\marti\AppData\Local\Microsoft\WindowsApps\python.exe

# %%
# !cond
# Out:
# ^C

# %%
import pandas as pd

# %%
df=pd.read_excel('C:/Users/marti/Downloads/proyecciones-poblacion-bogota-desagreacion2024.xlsx',
                sheet_name='UPZ Bogota 2018_2024')
df
# Out:
#                                             Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0                                                  NaN        NaN        NaN
# 1    PROYECCIONES DE POBLACIÓN DE BOGOTÁ POR UPZ, S...        NaN        NaN
# 2                                                  NaN        NaN        NaN
# 3    PROYECCIONES DE POBLACIÓN DE BOGOTÁ POR UPZ. P...        NaN        NaN
# 4                                                  NaN        NaN        NaN
# ..                                                 ...        ...        ...
# 788                                         CAPELLANIA       2024        115
# 789                                             ALAMOS       2024        116
# 790                               AEROPUERTO EL DORADO       2024        117
# 791                                                NaN        NaN        NaN
# 792                                      Fuente: DANE.        NaN        NaN
#
# ...

# %%
df = df[df['Unnamed: 1'].isna()==False]
df.columns = list(df.iloc[0,])
df = df.iloc[1:,]
df
# Out:
#                AREA GEOGRÁFICA   AÑO  UPZ LOC Hombres_0-4 Hombres_5-9  \
# 7    PASEO DE LOS LIBERTADORES  2018  001  01          84          94
# 8                  LA ACADEMIA  2018  002  11         125         203
# 9                    GUAYMARAL  2018  003  11          31          76
# 10                    VERBENAL  2018  009  01        4162        4103
# 11                    LA URIBE  2018  010  01         929         850
# ..                         ...   ...  ...  ..         ...         ...
# 786                    BAVARIA  2024  113  08         717        1096
# 787                    MODELIA  2024  114  09         843         907
# 788                 CAPELLANIA  2024  115  09         415         403
# 789                     ALAMOS  2024  116  10         198         289
# 790       AEROPUERTO EL DORADO  2024  117  09          11          14
#
#     Hombres_10-14 Hombres_15-19 Hombres_20-24 Hombres_25-29  ... Total_70-74  \
# ...

# %%
len(df['AREA GEOGRÁFICA'].unique())
# Out:
# 112

# %%
grouped_df = df.groupby(['AREA GEOGRÁFICA','AÑO','UPZ','LOC']).sum()
grouped_df
# Out:
#                               Hombres_0-4  Hombres_5-9  Hombres_10-14  \
# AREA GEOGRÁFICA AÑO  UPZ LOC
# 20 DE JULIO     2018 034 04          2575         2595           2702
#                 2019 034 04          2642         2596           2648
#                 2020 034 04          2679         2579           2585
#                 2021 034 04          2762         2538           2516
#                 2022 034 04          2837         2512           2452
# ...                                   ...          ...            ...
# ZONA INDUSTRIAL 2020 108 16           210          226            246
#                 2021 108 16           214          227            245
#                 2022 108 16           219          227            249
#                 2023 108 16           225          228            247
#                 2024 108 16           230          228            245
#
#                               Hombres_15-19  Hombres_20-24  Hombres_25-29  \
# ...

# %%
import geopandas as gpd
import pandas as pd

# %%
upzs = gpd.read_file('C:/Users/marti/Downloads/poblacion-upz-bogota.geojson')
upzs
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 upzs = gpd.read_file('C:/Users/marti/Downloads/poblacion-upz-bogota.geojson')
#       2 upzs
#
# File ~\miniconda3\lib\site-packages\geopandas\io\file.py:271, in _read_file(filename, bbox, mask, rows, engine, **kwargs)
#     181 def _read_file(filename, bbox=None, mask=None, rows=None, engine=None, **kwargs):
#     182     """
#     183     Returns a GeoDataFrame from a file or URL.
#     184
#    (...)
#     269
#     270     """
# --> 271     engine = _check_engine(engine, "'read_file' function")
#     273     filename = _expand_user(filename)
#     275     from_bytes = False
#
# File ~\miniconda3\lib\site-packages\geopandas\io\file.py:120, in _check_engine(engine, func)
#     118     _check_pyogrio(func)
#     119 elif engine is None:
# --> 120     raise ImportError(
# ...
